# %% [markdown]
# #### Projeto Analise Dados Ecommerce

# %%
# import lib
import pandas as np # analse de dados
import numpy as np
import matplotlib.pyplot as plt # visualizacao de dados
import seaborn as sns # visualizacao de dados
